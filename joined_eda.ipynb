# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import numpy as np
import scipy as sp
import pandas as pd
import sklearn as sk
import matplotlib as mpl
import matplotlib.pylab as plt
import matplotlib.font_manager as fm
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
sns.set(rc={'figure.figsize':(13.7,10.27)})
sns.set_style("whitegrid")
sns.set_color_codes()

# %%
from dask.distributed import Client
import dask.bag as db
import dask.dataframe as dd
import dask

from ast import literal_eval
from collections.abc import MutableMapping
import dask.array as da
# import h5py
import os

import reverse_geocode

# %%
Client()
# Out:
# <Client: 'tcp://127.0.0.1:33039' processes=4 threads=4, memory=20.70 GB>

# %% [markdown]
# # Load all datasets

# %% [markdown]
# ## Respective schemas

# %%
users={'userName': str,
      'jobs': object,
      'currentPlace': object,
      'previousPlaces': object,
      'education': object,
      'gPlusUserId': str}
reviews={'rating': float,
       'reviewerName': str,
       'reviewText': str,
       'categories': object,
       'gPlusPlaceId': str,
       'unixReviewTime': object,
       'reviewTime': str,
       'gPlusUserId': str}
places={'name': str,
       'price': str,
       'address': str,
       'hours': object,
       'phone': str,
       'closed': bool,
       'gPlusPlaceId': str,
       'gps': object}

# del users, reviews, places

# %% [markdown]
# ## Fastload of smaller files

# %%
# %%time

# 1 min

users_df = dd.read_csv('users/*.csv',
                 blocksize='128MiB',
                 dtype=users,
                 encoding='utf-8',
                 lineterminator='\n').compute()
# reviews_df = dd.read_csv('reviews/*.csv',
reviews_df = dd.read_csv('reviews_restaurants/*.csv',
                 blocksize='32MiB',
                 dtype=reviews,
                 encoding='utf-8',
                 lineterminator='\n').compute()
places_df = dd.read_csv('places/*.csv',
                 blocksize='64MiB',
                 dtype=places,
                 encoding='utf-8',
                 lineterminator='\n').compute()
# del users_df, reviews_df, places_df
# Out:
# CPU times: user 12 s, sys: 4.42 s, total: 16.4 s
# Wall time: 43.1 s

# %% [markdown]
# ## Preprocessing
#
# - Users: currentPlace => user_lat, user_long
# - Places: gps => places_lat, places_long
# - Joined: 'Country' column based on place reviewed
#
# **IDEA**: Merge restaurant types
#
# e.g.
# - Ice cream shop, Bakery, Dessert Shop => Dessert Shop
# - Thai, South Asian, Southeast Asian, Japanese, Chinese => Asian
# - etc...

# %%
print('Users: ', users_df.columns.to_list())
print('Places: ', places_df.columns.to_list())
print('Reviews: ', reviews_df.columns.to_list(), '\n')

# extract userName, currentPlace, gPlusUserId from users
users_df2 = users_df.drop(['jobs', 'previousPlaces', 'education'], axis=1)

# extract name, price, address, gPlusPlaceId, gps
places_df2 = places_df.drop(['hours', 'phone', 'closed'], axis=1)

# extract rating, categories, gPlusPlaceId, gPlusUserId
reviews_df2 = reviews_df.drop(['reviewerName', 'reviewText', 'unixReviewTime', 'reviewTime'], axis=1)

print('After dropping...')
print('Users: ', users_df2.columns.to_list())
print('Places: ', places_df2.columns.to_list())
print('Reviews: ', reviews_df2.columns.to_list())

# users_df2
# places_df2
reviews_df2.head()
# del users_df2, places_df2, reviews_df2
# Out:
# Users:  ['userName', 'jobs', 'currentPlace', 'previousPlaces', 'education', 'gPlusUserId']
# Places:  ['name', 'price', 'address', 'hours', 'phone', 'closed', 'gPlusPlaceId', 'gps']
# Reviews:  ['rating', 'reviewerName', 'reviewText', 'categories', 'gPlusPlaceId', 'unixReviewTime', 'reviewTime', 'gPlusUserId']
#
# After dropping...
# Users:  ['userName', 'currentPlace', 'gPlusUserId']
# Places:  ['name', 'price', 'address', 'gPlusPlaceId', 'gps']
# Reviews:  ['rating', 'categories', 'gPlusPlaceId', 'gPlusUserId']
#    rating                                         categories  \
# 0     4.0         ['Asian Restaurant', 'Chinese Restaurant']
# 1     5.0  ['European Restaurant', 'Italian Restaurant', ...
# 2     5.0                            ['Barbecue Restaurant']
# 3     4.0                                     ['Restaurant']
# 4     5.0                             ['Mexican Restaurant']
#
#             gPlusPlaceId            gPlusUserId
# 0  106591714648856494903  100000032416892623125
# 1  109420033090810328045  100000032416892623125
# 2  111623070919810985923  100000032416892623125
# 3  113854191152597312098  100000032416892623125
# 4  115827996910815192564  100000032416892623125

# %% [markdown]
# ### Users: Gps column => Lat, Long columns

# %%
# %%time

def string_to_coord(currentPlace):
    coord = None
    lat = long = None
    try:
        coord = eval(currentPlace)[1][1:3]
        lat, long = coord[0]/10000000, coord[1]/10000000
    except Exception as e:
        return (lat, long)
    return (lat, long)

users_df2['Coordinates'] = users_df2['currentPlace'].map(string_to_coord)
users_df2['user_lat'] = users_df2['Coordinates'].apply(lambda x : x[0])
users_df2['user_long'] = users_df2['Coordinates'].apply(lambda x : x[1])

users_df2.head()
# Out:
# CPU times: user 12.3 s, sys: 222 ms, total: 12.5 s
# Wall time: 12.4 s
#            userName                                       currentPlace  \
# 0            an lam  ['Thành phố Hồ Chí Minh, Việt Nam', [[], 10823...
# 1      HALİL TURGUT           ['Adana', [[], 370000000, 353213330, 1]]
# 2             森田さとこ                                                NaN
# 3         amey kore                                                NaN
# 4  william spindler                                                NaN
#
#              gPlusUserId              Coordinates   user_lat   user_long
# 0  100000010817154263736  (10.823099, 106.629664)  10.823099  106.629664
# 1  100000013500285534661        (37.0, 35.321333)  37.000000   35.321333
# 2  100000021336848867366             (None, None)        NaN         NaN
# 3  100000030557048145331             (None, None)        NaN         NaN
# 4  100000032416892623125             (None, None)        NaN         NaN

# %% [markdown]
# ## Places: Gps column => Lat, Long columns

# %%
# %%time

def string_to_coord2(gps):
    coord = None
    lat = long = None
    try:
        coord = eval(gps)
        lat, long = coord[0]/1000000, coord[1]/1000000
    except Exception as e:
        return (lat, long)
    return (lat, long)

places_df2['Coordinates'] = places_df2['gps'].map(string_to_coord2)
places_df2['place_lat'] = places_df2['Coordinates'].apply(lambda x : x[0])
places_df2['place_long'] = places_df2['Coordinates'].apply(lambda x : x[1])

places_df2.head()
# Out:
# CPU times: user 20.7 s, sys: 337 ms, total: 21.1 s
# Wall time: 20.9 s
#                            name price  \
# 0    Diamond Valley Lake Marina   NaN
# 1          Blue Ribbon Cleaners   NaN
# 2                     Portofino   NaN
# 3      T C's Referee Sports Bar    $$
# 4  Carrefour - Palembang Square   NaN
#
#                                              address           gPlusPlaceId  \
# 0             ['2615 Angler Ave', 'Hemet, CA 92545']  104699454385822125632
# 1                        ['Parole', 'Annapolis, MD']  103054478949000078829
# 2  ['ул. Тутаева, 1', 'Nazran, Ingushetia, Russia...  109810290098030327104
# 3        ['5322 W 26th St', 'Sioux Falls, SD 57106']  100327153115986850675
# 4  ['Jl. Angkatan 45', 'Kompleks Palembang Square...  103368487323937936043
#
#                         gps                               Coordinates  \
# 0  [33.703804, -117.003209]          (3.3703804e-05, -0.000117003209)
# 1   [38.979759, -76.547538]  (3.8979759000000004e-05, -7.6547538e-05)
# 2     [43.22776, 44.762726]   (4.3227760000000004e-05, 4.4762726e-05)
# 3   [43.529494, -96.792244]   (4.3529494e-05, -9.679224399999999e-05)
# 4   [-2.976256, 104.742662]   (-2.976256e-06, 0.00010474266199999999)
#
#    place_lat  place_long
# 0   0.000034   -0.000117
# 1   0.000039   -0.000077
# 2   0.000043    0.000045
# 3   0.000044   -0.000097
# 4  -0.000003    0.000105

# %% [markdown]
# ### Drop redundant columns and join

# %%
# %%time
users_df3 = users_df2.drop(['currentPlace', 'Coordinates'], axis=1)
places_df3 = places_df2.drop(['gps', 'Coordinates'], axis=1)

joined_df = reviews_df.merge(users_df3,
                            how='left',
                            on='gPlusUserId').merge(places_df3,
                                                   how='left',
                                                   on='gPlusPlaceId')
joined_df
# Out:
# CPU times: user 14.2 s, sys: 1.19 s, total: 15.4 s
# Wall time: 15.5 s
#          rating      reviewerName  \
# 0           4.0  william spindler
# 1           5.0  william spindler
# 2           5.0  william spindler
# 3           4.0  william spindler
# 4           5.0  william spindler
# ...         ...               ...
# 4110767     2.0  charles mckinney
# 4110768     2.0  charles mckinney
# 4110769     4.0  charles mckinney
# 4110770     1.0  charles mckinney
# 4110771     1.0  charles mckinney
#
#                                                 reviewText  \
# 0                        Best War Wanton soup in Red Bluff
# 1        This is a review that is long overdo. I've bee...
# 2        Some authentic rub BBQ, great food and don't m...
# 3        Truly a Red Bluff standard. Great old fashione...
# 4        Long time favorite Mexican food, always consis...
# ...                                                    ...
# 4110767              Too expensive for a fast food burger.
# 4110768                                                NaN
# 4110769                                                NaN
# 4110770  i will never go back. food and customer servic...
# 4110771                                                NaN
#
#                                                 categories  \
# 0               ['Asian Restaurant', 'Chinese Restaurant']
# 1        ['European Restaurant', 'Italian Restaurant', ...
# 2                                  ['Barbecue Restaurant']
# 3                                           ['Restaurant']
# 4                                   ['Mexican Restaurant']
# ...                                                    ...
# 4110767   ['Hamburger Restaurant', 'Fast Food Restaurant']
# 4110768  ['Mexican Restaurant', 'Latin American Restaur...
# 4110769  ['Hot Dog Restaurant', 'Takeout Restaurant', '...
# 4110770       ['Buffet Restaurant', 'American Restaurant']
# 4110771  ['Mexican Restaurant', 'Latin American Restaur...
#
#                   gPlusPlaceId unixReviewTime    reviewTime  \
# 0        106591714648856494903   1394669496.0  Mar 12, 2014
# 1        109420033090810328045   1394826388.0  Mar 14, 2014
# 2        111623070919810985923   1394671215.0  Mar 12, 2014
# 3        113854191152597312098   1394670357.0  Mar 12, 2014
# 4        115827996910815192564   1394669713.0  Mar 12, 2014
# ...                        ...            ...           ...
# 4110767  116458473784504954830   1364706351.0  Mar 30, 2013
# 4110768  117332598175065149705   1368434855.0  May 13, 2013
# 4110769  117868066122653879601   1317841949.0   Oct 5, 2011
# 4110770  117952004983617019485   1315602371.0   Sep 9, 2011
# 4110771  118224418815687780032   1315602876.0   Sep 9, 2011
#
#                    gPlusUserId          userName  user_lat  user_long  \
# 0        100000032416892623125  william spindler       NaN        NaN
# 1        100000032416892623125  william spindler       NaN        NaN
# 2        100000032416892623125  william spindler       NaN        NaN
# 3        100000032416892623125  william spindler       NaN        NaN
# 4        100000032416892623125  william spindler       NaN        NaN
# ...                        ...               ...       ...        ...
# 4110767  118446742455312620560               NaN       NaN        NaN
# 4110768  118446742455312620560               NaN       NaN        NaN
# 4110769  118446742455312620560               NaN       NaN        NaN
# 4110770  118446742455312620560               NaN       NaN        NaN
# 4110771  118446742455312620560               NaN       NaN        NaN
#
#                               name price  \
# 0        Peking Chinese Restaurant   $$$
# 1                  Firehouse Pizza    $$
# 2                Two Buds Barbeque   NaN
# 3                 Bud's Jolly Kone   NaN
# 4                        La Corona    $$
# ...                            ...   ...
# 4110767                  Fatburger   NaN
# 4110768                  Super Mex   NaN
# 4110769            Wienerschnitzel   $$$
# 4110770            HomeTown Buffet    $$
# 4110771              El Gallo Giro   $$$
#
#                                                    address  place_lat  \
# 0                   ['860 Main St', 'Red Bluff, CA 96080']   0.000040
# 1                   ['734 Main St', 'Red Bluff, CA 96080']   0.000040
# 2           ['22825 Antelope Blvd', 'Red Bluff, CA 96080']   0.000040
# 3             ['455 Antelope Blvd', 'Red Bluff, CA 96080']   0.000040
# 4                 ['914 Walnut St', 'Red Bluff, CA 96080']   0.000040
# ...                                                    ...        ...
# 4110767        ['6780 Cherry Ave', 'Long Beach, CA 90805']   0.000034
# 4110768      ['5660 Atlantic Ave', 'Long Beach, CA 90805']   0.000034
# 4110769      ['1300 E Rosecrans Ave', 'Compton, CA 90221']   0.000034
# 4110770       ['3102 E Imperial Hwy', 'Lynwood, CA 90262']   0.000034
# 4110771  ['7148 Pacific Blvd', 'Huntington Park, CA 902...   0.000034
#
#          place_long
# 0         -0.000122
# 1         -0.000122
# 2         -0.000122
# 3         -0.000122
# 4         -0.000122
# ...             ...
# 4110767   -0.000118
# 4110768   -0.000118
# 4110769   -0.000118
# 4110770   -0.000118
# 4110771   -0.000118
#
# [4110772 rows x 16 columns]

# %% [markdown]
# # Finish the joined EDA
